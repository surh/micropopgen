# %%
import pandas as pd

file = '/home/sur/micropopgen/exp/2017/today4/comparisons.txt'
file

# %%
comparisons = pd.read_csv(file, sep="\t")
comparisons.head()
# Out:
#                A                     B                            Species
# 0  Buccal mucosa  Supragingival plaque          Veillonella_parvula_57794
# 1  Buccal mucosa  Supragingival plaque             Porphyromonas_sp_57899
# 2  Buccal mucosa  Supragingival plaque         Streptococcus_oralis_58560
# 3  Buccal mucosa  Supragingival plaque  Fusobacterium_periodonticum_58002
# 4  Buccal mucosa  Supragingival plaque          Gemella_haemolysans_61816

# %%
for i, r in comparisons.iterrows():
    print(i)
    print(r)
# Out:
# 0
# A                      Buccal mucosa
# B               Supragingival plaque
# Species    Veillonella_parvula_57794
# Name: 0, dtype: object
# 1
# A                   Buccal mucosa
# B            Supragingival plaque
# Species    Porphyromonas_sp_57899
# Name: 1, dtype: object
# 2
# A                       Buccal mucosa
# B                Supragingival plaque
# Species    Streptococcus_oralis_58560
# Name: 2, dtype: object
# 3
# A                              Buccal mucosa
# B                       Supragingival plaque
# Species    Fusobacterium_periodonticum_58002
# Name: 3, dtype: object
# 4
# A                      Buccal mucosa
# B               Supragingival plaque
# Species    Gemella_haemolysans_61816
# Name: 4, dtype: object
# 5
# A                             Buccal mucosa
# B                      Supragingival plaque
# Species    Haemophilus_parainfluenzae_62356
# Name: 5, dtype: object
# 6
# A                      Buccal mucosa
# B               Supragingival plaque
# ...

# %%
# Out:
# 'Species'
