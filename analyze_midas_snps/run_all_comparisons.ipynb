# %%
import pandas as pd
import argparse
import os
import sutilspy

# %%
comparisons_file = '/home/sur/micropopgen/exp/2017/today4/comparisons.txt'
indir = '/godot/hmp/midas/merged.snps/'
map_file = '/home/sur/micropopgen/exp/2017/today4/full_map.txt'
mk_bin = '/home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py'
outdir = './out/'

# parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
# required = parser.add_argument_group("Required arguments")
# required.add_argument("--comparisons", help = "File with comparisons to make",
#                       type = str, required = True)
# #     required.add_argument("--metadata_file", help = "Mapping file for samples", type = str,
# #                           required = True)
# #     required.add_argument("--group1", help = "Group1 of comparison", type = str,
# #                           required = True)
# #     required.add_argument("--group2", help = "Group2 of comparison",
# #                           required = True)
        
# #     parser.add_argument("--test", help = "Eventually specify test to perform",
# #                         default = "G", type = str)
# #     parser.add_argument("--outfile", help = "Output file with results",
# #                    default = "mk_results.txt", type = str)
# #     parser.add_argument("--min_count", help = "min depth at a position in a sample to consider that sample in that position",
# #                         default = 1, type = int)
# #     parser.add_argument("--nrows", help = "Number of gene positions to read",
# #                         default = float('inf'), type = float)
# #     parser.add_argument("--tables", help = "Output file for contingency tables",
# #                         default = "mk_tables.txt", type = str)
# #     parser.add_argument("--pseudocount", help = "Pseudocount value to use in contingency tables",
# #                         default = 1, type = int)
# args = parser.parse_args()

# %%
comparisons = pd.read_csv(comparisons_file, sep="\t")
comparisons.head()
# Out:
#                A                     B                            Species
# 0  Buccal mucosa  Supragingival plaque          Veillonella_parvula_57794
# 1  Buccal mucosa  Supragingival plaque             Porphyromonas_sp_57899
# 2  Buccal mucosa  Supragingival plaque         Streptococcus_oralis_58560
# 3  Buccal mucosa  Supragingival plaque  Fusobacterium_periodonticum_58002
# 4  Buccal mucosa  Supragingival plaque          Gemella_haemolysans_61816

# %%
for i, r in comparisons.iterrows():
    #print(i)
    #print(r)
    
    species_indir = ''.join([indir,'/',r['Species'], '/'])
    #print(species_dir)
    
    # Create output directory
    species_outdir = ''.join([outdir,'/',r['Species'],'/'])
    try:
        os.mkdir(species_outdir)
        print("Creating output directory")
    except FileExistsError:
        print("Directory already exists")
    
    suffix = r['A'] + '_' + r['B']
    suffix = suffix.replace(' ','.')
    #print(suffix)
        
    species_outfile = ''.join([species_outdir,
                               '/','mk_results.',
                               suffix,'.txt'])
    species_tables = ''.join([species_outdir,'/',
                              'mk_tables.',suffix,
                              '.txt'])
    species_log = ''.join([species_outdir,'/',
                           suffix,'.log'])
    species_err = ''.join([species_outdir,'/',
                           suffix,'.err'])
    
    cmd = [mk_bin, '--indir', species_dir,
          '--metadata_file', map_file,
           '--group1', r['A'],
           '--group2', r['B'],
           '--outfile', species_outfile,
           '--tables', species_tables,
           '1>', species_log,
           '2>', species_err]
    cmd = ' '.join(cmd)
    #print(cmd)
    sutilspy.io.run_command(cmd)
    
    #/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps/Porphyromonas_sp_57899/ --metadata_file map.txt --group1 'Supragingival plaque' --group2 'Tongue dorsum' --outfile Porphyromonas_sp_57899_mk_results.txt --tables Porphyromonas_sp_57899_mk_tables.txt 1> log 2> err
# Out:
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Veillonella_parvula_57794//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Veillonella_parvula_57794//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Veillonella_parvula_57794//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Veillonella_parvula_57794//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Porphyromonas_sp_57899//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Porphyromonas_sp_57899//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Porphyromonas_sp_57899//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Porphyromonas_sp_57899//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Streptococcus_oralis_58560//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Streptococcus_oralis_58560//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Streptococcus_oralis_58560//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Streptococcus_oralis_58560//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Fusobacterium_periodonticum_58002//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Fusobacterium_periodonticum_58002//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Fusobacterium_periodonticum_58002//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Fusobacterium_periodonticum_58002//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Gemella_haemolysans_61816//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Gemella_haemolysans_61816//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Gemella_haemolysans_61816//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Gemella_haemolysans_61816//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Haemophilus_parainfluenzae_62356//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Haemophilus_parainfluenzae_62356//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Haemophilus_parainfluenzae_62356//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Haemophilus_parainfluenzae_62356//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Veillonella_parvula_58184//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Veillonella_parvula_58184//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Veillonella_parvula_58184//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Veillonella_parvula_58184//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Haemophilus_parainfluenzae_57123//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Haemophilus_parainfluenzae_57123//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Haemophilus_parainfluenzae_57123//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Haemophilus_parainfluenzae_57123//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Haemophilus_haemolyticus_58348//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Haemophilus_haemolyticus_58348//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Haemophilus_haemolyticus_58348//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Haemophilus_haemolyticus_58348//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Haemophilus_parainfluenzae_62468//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Haemophilus_parainfluenzae_62468//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Haemophilus_parainfluenzae_62468//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Haemophilus_parainfluenzae_62468//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Supragingival plaque --outfile ./out//Rothia_dentocariosa_57938//mk_results.Buccal.mucosa_Supragingival.plaque.txt --tables ./out//Rothia_dentocariosa_57938//mk_tables.Buccal.mucosa_Supragingival.plaque.txt 1> ./out//Rothia_dentocariosa_57938//Buccal.mucosa_Supragingival.plaque.log 2> ./out//Rothia_dentocariosa_57938//Buccal.mucosa_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Prevotella_melaninogenica_58075//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Prevotella_melaninogenica_58075//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Prevotella_melaninogenica_58075//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Prevotella_melaninogenica_58075//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Porphyromonas_sp_57899//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Porphyromonas_sp_57899//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Porphyromonas_sp_57899//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Porphyromonas_sp_57899//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Fusobacterium_periodonticum_58002//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Fusobacterium_periodonticum_58002//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Fusobacterium_periodonticum_58002//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Fusobacterium_periodonticum_58002//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Rothia_mucilaginosa_62109//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Rothia_mucilaginosa_62109//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Rothia_mucilaginosa_62109//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Rothia_mucilaginosa_62109//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_haemolyticus_58352//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_haemolyticus_58352//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_haemolyticus_58352//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_haemolyticus_58352//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_haemolyticus_58351//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_haemolyticus_58351//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_haemolyticus_58351//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_haemolyticus_58351//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Rothia_mucilaginosa_58144//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Rothia_mucilaginosa_58144//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Rothia_mucilaginosa_58144//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Rothia_mucilaginosa_58144//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_parainfluenzae_62356//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_parainfluenzae_62356//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_parainfluenzae_62356//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_parainfluenzae_62356//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_influenzae_60134//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_influenzae_60134//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_influenzae_60134//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_influenzae_60134//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_parainfluenzae_57123//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_parainfluenzae_57123//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_parainfluenzae_57123//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_parainfluenzae_57123//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_haemolyticus_58348//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_haemolyticus_58348//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_haemolyticus_58348//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_haemolyticus_58348//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_haemolyticus_58349//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_haemolyticus_58349//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_haemolyticus_58349//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_haemolyticus_58349//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Buccal mucosa --group2 Tongue dorsum --outfile ./out//Haemophilus_parainfluenzae_62468//mk_results.Buccal.mucosa_Tongue.dorsum.txt --tables ./out//Haemophilus_parainfluenzae_62468//mk_tables.Buccal.mucosa_Tongue.dorsum.txt 1> ./out//Haemophilus_parainfluenzae_62468//Buccal.mucosa_Tongue.dorsum.log 2> ./out//Haemophilus_parainfluenzae_62468//Buccal.mucosa_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Stool --group2 Supragingival plaque --outfile ./out//Dialister_invisus_61905//mk_results.Stool_Supragingival.plaque.txt --tables ./out//Dialister_invisus_61905//mk_tables.Stool_Supragingival.plaque.txt 1> ./out//Dialister_invisus_61905//Stool_Supragingival.plaque.log 2> ./out//Dialister_invisus_61905//Stool_Supragingival.plaque.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Neisseria_mucosa_61504//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Neisseria_mucosa_61504//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Neisseria_mucosa_61504//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Neisseria_mucosa_61504//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Porphyromonas_sp_57899//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Porphyromonas_sp_57899//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Porphyromonas_sp_57899//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Porphyromonas_sp_57899//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Fusobacterium_periodonticum_58002//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Fusobacterium_periodonticum_58002//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Fusobacterium_periodonticum_58002//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Fusobacterium_periodonticum_58002//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Actinomyces_odontolyticus_57475//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Actinomyces_odontolyticus_57475//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Actinomyces_odontolyticus_57475//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Actinomyces_odontolyticus_57475//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Neisseria_mucosa_61632//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Neisseria_mucosa_61632//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Neisseria_mucosa_61632//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Neisseria_mucosa_61632//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Neisseria_subflava_61760//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Neisseria_subflava_61760//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Neisseria_subflava_61760//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Neisseria_subflava_61760//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Tannerella_sp_60461//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Tannerella_sp_60461//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Tannerella_sp_60461//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Tannerella_sp_60461//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Haemophilus_parainfluenzae_62356//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Haemophilus_parainfluenzae_62356//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Haemophilus_parainfluenzae_62356//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Haemophilus_parainfluenzae_62356//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Fusobacterium_periodonticum_61765//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Fusobacterium_periodonticum_61765//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Fusobacterium_periodonticum_61765//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Fusobacterium_periodonticum_61765//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Granulicatella_adiacens_61980//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Granulicatella_adiacens_61980//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Granulicatella_adiacens_61980//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Granulicatella_adiacens_61980//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Capnocytophaga_gingivalis_61780//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Capnocytophaga_gingivalis_61780//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Capnocytophaga_gingivalis_61780//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Capnocytophaga_gingivalis_61780//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Haemophilus_parainfluenzae_57123//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Haemophilus_parainfluenzae_57123//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Haemophilus_parainfluenzae_57123//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Haemophilus_parainfluenzae_57123//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Neisseria_flavescens_61924//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Neisseria_flavescens_61924//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Neisseria_flavescens_61924//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Neisseria_flavescens_61924//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Haemophilus_haemolyticus_58348//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Haemophilus_haemolyticus_58348//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Haemophilus_haemolyticus_58348//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Haemophilus_haemolyticus_58348//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Haemophilus_parainfluenzae_62468//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Haemophilus_parainfluenzae_62468//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Haemophilus_parainfluenzae_62468//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Haemophilus_parainfluenzae_62468//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Capnocytophaga_sputigena_61779//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Capnocytophaga_sputigena_61779//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Capnocytophaga_sputigena_61779//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Capnocytophaga_sputigena_61779//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Leptotrichia_wadei_57378//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Leptotrichia_wadei_57378//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Leptotrichia_wadei_57378//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Leptotrichia_wadei_57378//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Neisseria_flavescens_61757//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Neisseria_flavescens_61757//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Neisseria_flavescens_61757//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Neisseria_flavescens_61757//Supragingival.plaque_Tongue.dorsum.err
# Directory already exists
# /home/sur/micropopgen/src/micropopgen/analyze_midas_snps/MKtest.py --indir /godot/hmp/midas/merged.snps//Prevotella_tannerae_61946/ --metadata_file /home/sur/micropopgen/exp/2017/today4/full_map.txt --group1 Supragingival plaque --group2 Tongue dorsum --outfile ./out//Prevotella_tannerae_61946//mk_results.Supragingival.plaque_Tongue.dorsum.txt --tables ./out//Prevotella_tannerae_61946//mk_tables.Supragingival.plaque_Tongue.dorsum.txt 1> ./out//Prevotella_tannerae_61946//Supragingival.plaque_Tongue.dorsum.log 2> ./out//Prevotella_tannerae_61946//Supragingival.plaque_Tongue.dorsum.err

# %%
i
